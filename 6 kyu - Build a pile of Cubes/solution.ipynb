# %% [markdown]
# ![description.PNG](attachment:5758d3ea-79d2-4a29-9686-557e6efa8d59.PNG)

# %%
def find_nb(m):
    count_n = 0
    while m>0:
        m -= (count_n+1)**3
        count_n += 1
    if not m:
        return count_n
    else:
        return -1
